# %%
import pandas as pd
import seaborn as Sns
import numpy as np 
import matplotlib.pyplot as plt

# %%
DataFrame=pd.read_csv(r"C:\Users\Dinesh\Desktop\Ds\Zomato data .csv")

# %%
print(DataFrame)
# Out:
#                       name online_order book_table   rate  votes  \
# 0                    Jalsa          Yes        Yes  4.1/5    775
# 1           Spice Elephant          Yes         No  4.1/5    787
# 2          San Churro Cafe          Yes         No  3.8/5    918
# 3    Addhuri Udupi Bhojana           No         No  3.7/5     88
# 4            Grand Village           No         No  3.8/5    166
# ..                     ...          ...        ...    ...    ...
# 143       Melting Melodies           No         No  3.3/5      0
# 144        New Indraprasta           No         No  3.3/5      0
# 145           Anna Kuteera          Yes         No  4.0/5    771
# 146                 Darbar           No         No  3.0/5     98
# 147          Vijayalakshmi          Yes         No  3.9/5     47
#
#      approx_cost(for two people) listed_in(type)
# 0                            800          Buffet
# 1                            800          Buffet
# ...

# %%
def handleRate(value):
    value=str(value).split('/')
    value=value[0]
    return float(value)
DataFrame['rate']=DataFrame['rate'].apply(handleRate)
print(DataFrame.head)
# Out:
# <bound method NDFrame.head of                       name online_order book_table  rate  votes  \
# 0                    Jalsa          Yes        Yes   4.1    775
# 1           Spice Elephant          Yes         No   4.1    787
# 2          San Churro Cafe          Yes         No   3.8    918
# 3    Addhuri Udupi Bhojana           No         No   3.7     88
# 4            Grand Village           No         No   3.8    166
# ..                     ...          ...        ...   ...    ...
# 143       Melting Melodies           No         No   3.3      0
# 144        New Indraprasta           No         No   3.3      0
# 145           Anna Kuteera          Yes         No   4.0    771
# 146                 Darbar           No         No   3.0     98
# 147          Vijayalakshmi          Yes         No   3.9     47
#
#      approx_cost(for two people) listed_in(type)
# 0                            800          Buffet
# 1                            800          Buffet
# ...

# %%
DataFrame.info
# Out:
# <bound method DataFrame.info of                       name online_order book_table  rate  votes  \
# 0                    Jalsa          Yes        Yes   4.1    775
# 1           Spice Elephant          Yes         No   4.1    787
# 2          San Churro Cafe          Yes         No   3.8    918
# 3    Addhuri Udupi Bhojana           No         No   3.7     88
# 4            Grand Village           No         No   3.8    166
# ..                     ...          ...        ...   ...    ...
# 143       Melting Melodies           No         No   3.3      0
# 144        New Indraprasta           No         No   3.3      0
# 145           Anna Kuteera          Yes         No   4.0    771
# 146                 Darbar           No         No   3.0     98
# 147          Vijayalakshmi          Yes         No   3.9     47
#
#      approx_cost(for two people) listed_in(type)
# 0                            800          Buffet
# 1                            800          Buffet
# ...

# %%
Sns.countplot(x=DataFrame['listed_in(type)'])
plt.xlabel("type of resturant")
# Out:
# Text(0.5, 0, 'type of resturant')

# %%
Sns.countplot(x=DataFrame['approx_cost(for two people)'])
# Out:
# <Axes: xlabel='approx_cost(for two people)', ylabel='count'>

# %%
groupdata=DataFrame.groupby('listed_in(type)')['votes'].sum
max_votes=DataFrame['votes'].max()
Restuarant_wid_max_vote=DataFrame.loc[DataFrame['votes']==max_votes,'name']
print(Restuarant_wid_max_vote)
# Out:
# 38    Empire Restaurant
# Name: name, dtype: object

# %%
Sns.countplot(x=DataFrame['online_order'])
# Out:
# <Axes: xlabel='online_order', ylabel='count'>

# %%
plt.hist(DataFrame['rate'])
# Out:
# (array([ 1.,  9.,  9., 21., 18., 26., 30., 21.,  9.,  4.]),
#  array([2.6, 2.8, 3. , 3.2, 3.4, 3.6, 3.8, 4. , 4.2, 4.4, 4.6]),
#  <BarContainer object of 10 artists>)

# %%
Sns.countplot(x=DataFrame['approx_cost(for two people)'])
# Out:
# <Axes: xlabel='approx_cost(for two people)', ylabel='count'>

# %%
Sns.boxplot(x=DataFrame['online_order'],y=DataFrame['rate'])
# Out:
# <Axes: xlabel='online_order', ylabel='rate'>

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 Sns.heatmap(x=DataFrame['listed_in(type)'],y=DataFrame['online_order'], data=DataFrame)
#
# File c:\Users\Dinesh\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\matrix.py:446, in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     365 """Plot rectangular data as a color-encoded matrix.
#     366
#     367 This is an Axes-level function and will draw the heatmap into the
#    (...)
#     443
#     444 """
#     445 # Initialize the plotter object
# --> 446 plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     447                       annot_kws, cbar, cbar_kws, xticklabels,
#     448                       yticklabels, mask)
# ...
